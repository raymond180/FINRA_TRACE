# %%
import pandas as pd
import numpy as np

from manage_path import *
from topic_model_analysis import *

# %%
result_directory = get_result_directory()
get_document_item_vectorize = np.vectorize(get_document_item)

# %%
Dc_v3 = pd.read_csv(result_directory/'Dc_v3_50topics.csv',index_col=0)

# %%
Dc_v3['dealer'] = pd.Series(list(zip(get_document_item_vectorize(Dc_v3.index,0),get_document_item_vectorize(Dc_v3.index,2)))).values
Dc_v3.index = pd.to_datetime(get_document_item_vectorize(Dc_v3.index,1))

# %%
dealer_mean_75quantile = Dc_v3.groupby(['dealer']).mean().quantile(0.75,axis=0)

# %%
dealer_mean_75quantile.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d91c0146053> in <module>
# ----> 1 dealer_mean_75quantile.head(3)
#
# NameError: name 'dealer_mean_75quantile' is not defined

# %%
dealer_mean = Dc_v3.groupby(['dealer']).mean()

# %%
dealer_mean.loc[dealer_mean in dealer_mean_75quantile]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-f63b2eadf1c3> in <module>
# ----> 1 dealer_mean.loc[dealer_mean in dealer_mean_75quantile]
#
# ~\Anaconda3\envs\topicModeling\lib\site-packages\pandas\core\generic.py in __contains__(self, key)
#    1520     def __contains__(self, key):
#    1521         """True if the key is in the info axis"""
# -> 1522         return key in self._info_axis
#    1523
#    1524     @property
#
# ~\Anaconda3\envs\topicModeling\lib\site-packages\pandas\core\indexes\base.py in __contains__(self, key)
#    2033     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    2034     def __contains__(self, key):
# -> 2035         hash(key)
#    2036         try:
#    2037             return key in self._engine
#
# ~\Anaconda3\envs\topicModeling\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed

# %%
Dc_v3.groupby(['dealer']).mean()
# Out:
#                   0         1         2         3         4         5  \
# dealer
# (10, B)         NaN       NaN       NaN       NaN       NaN  0.382500
# (10, S)         NaN       NaN  0.510000       NaN       NaN       NaN
# (1002, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1005, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1016, B)  0.529000  0.281568  0.334593  0.546768  0.402561  0.378722
# (1016, S)  0.558336  0.147342  0.366709  0.546769  0.402910  0.511796
# (1020, B)       NaN       NaN  0.201654       NaN       NaN       NaN
# (1020, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1023, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1023, S)  0.676330       NaN       NaN       NaN       NaN       NaN
# (1027, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1029, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1029, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1030, B)  0.261921  0.291118  0.462580  0.286517  0.352049  0.272880
# (1030, S)  0.255887  0.234192  0.214212  0.292547  0.163728  0.389266
# (1036, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1040, B)       NaN  0.340000       NaN       NaN       NaN       NaN
# (1040, S)  0.698810  0.510000  0.510000       NaN       NaN       NaN
# (1042, B)  0.750312  0.229805       NaN  0.191408  0.432787       NaN
# (1042, S)  0.718283  0.159910       NaN  0.165734  0.351214       NaN
# (1043, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1045, B)       NaN  0.510000  0.514653  0.173822       NaN       NaN
# (1045, S)       NaN       NaN       NaN  0.340000       NaN       NaN
# (1047, B)       NaN  0.510000       NaN       NaN       NaN       NaN
# (1047, S)  0.510000       NaN       NaN       NaN       NaN       NaN
# (1048, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1049, B)  0.265708  0.169822  0.170456  0.155735  0.239156       NaN
# (1049, S)  0.223043  0.170505  0.225795  0.168885  0.223308       NaN
# (1050, B)       NaN  0.673333       NaN       NaN       NaN       NaN
# (1050, S)       NaN       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# (949, S)   0.565059  0.510000  0.510000  0.591667  0.261377  0.510000
# (95, B)         NaN       NaN  0.912274       NaN       NaN  0.169183
# (95, S)         NaN       NaN       NaN       NaN       NaN       NaN
# (950, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (951, B)        NaN       NaN       NaN       NaN       NaN  0.510000
# (953, B)        NaN  0.510000       NaN       NaN       NaN  0.510000
# (953, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (956, B)        NaN  0.193099  0.510000       NaN       NaN       NaN
# (956, S)   0.510000       NaN  0.510000       NaN  0.144480  0.401461
# (960, B)        NaN  0.510000       NaN       NaN       NaN       NaN
# (960, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (962, B)        NaN  0.673333       NaN       NaN       NaN       NaN
# (962, S)   0.673333       NaN       NaN  0.510000       NaN       NaN
# (964, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (970, B)        NaN       NaN       NaN  0.510000       NaN       NaN
# (970, S)        NaN       NaN       NaN  0.510000       NaN       NaN
# (972, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (984, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (984, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (988, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (988, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (990, B)   0.510000  0.487038  0.520814  0.394553  0.208400       NaN
# (990, S)   0.491814  0.461429  0.302630       NaN  0.369411       NaN
# (993, B)   0.510000  0.353125  0.424711  0.510000  0.510000  0.510000
# (993, S)   0.657000  0.382500       NaN       NaN  0.510000  0.415948
# (995, B)   0.510000       NaN       NaN       NaN       NaN       NaN
# (995, S)   0.510000       NaN       NaN       NaN       NaN       NaN
# (996, B)        NaN  0.510000       NaN       NaN       NaN       NaN
# (996, S)        NaN       NaN  0.510000       NaN       NaN       NaN
# (999, S)        NaN       NaN       NaN       NaN       NaN       NaN
#
#                   6         7         8         9    ...           40  \
# dealer                                               ...
# (10, B)    0.510000       NaN       NaN       NaN    ...     0.510000
# (10, S)    0.439912       NaN  0.402265  0.508153    ...     0.510000
# (1002, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1005, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1016, B)  0.268905  0.398074  0.510000       NaN    ...     0.325975
# (1016, S)  0.382525  0.417694  0.510000       NaN    ...     0.510000
# (1020, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1020, S)       NaN       NaN       NaN       NaN    ...          NaN
# (1023, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1023, S)       NaN       NaN       NaN       NaN    ...          NaN
# (1027, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1029, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1029, S)       NaN       NaN       NaN       NaN    ...          NaN
# (1030, B)  0.234358  0.270467  0.417400  0.268899    ...     0.288516
# (1030, S)  0.236451  0.238838  0.479155  0.280545    ...     0.277494
# (1036, S)       NaN       NaN       NaN       NaN    ...          NaN
# (1040, B)  0.340000  0.510000       NaN       NaN    ...          NaN
# (1040, S)  0.139690       NaN       NaN       NaN    ...          NaN
# (1042, B)       NaN  0.211086       NaN       NaN    ...          NaN
# (1042, S)  0.356091  0.176595  0.256491       NaN    ...          NaN
# (1043, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1045, B)       NaN  0.364051       NaN       NaN    ...          NaN
# (1045, S)       NaN  0.340000       NaN       NaN    ...          NaN
# (1047, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1047, S)  0.510000       NaN       NaN       NaN    ...          NaN
# (1048, S)       NaN       NaN       NaN       NaN    ...          NaN
# (1049, B)  0.208233  0.133803       NaN       NaN    ...          NaN
# (1049, S)       NaN  0.161161       NaN       NaN    ...          NaN
# (1050, B)       NaN       NaN       NaN       NaN    ...          NaN
# (1050, S)       NaN       NaN       NaN       NaN    ...          NaN
# ...             ...       ...       ...       ...    ...          ...
# (949, S)   0.311667  0.506667  0.510000       NaN    ...     0.510000
# (95, B)         NaN       NaN  0.714325       NaN    ...     0.876139
# (95, S)         NaN       NaN  0.632500       NaN    ...     0.510000
# (950, S)        NaN       NaN       NaN       NaN    ...          NaN
# (951, B)        NaN       NaN       NaN       NaN    ...     0.465019
# (953, B)        NaN       NaN  0.510000       NaN    ...     0.376656
# (953, S)        NaN       NaN       NaN       NaN    ...          NaN
# (956, B)        NaN       NaN       NaN       NaN    ...          NaN
# (956, S)   0.186985       NaN       NaN       NaN    ...          NaN
# (960, B)        NaN       NaN       NaN       NaN    ...          NaN
# (960, S)        NaN       NaN       NaN       NaN    ...          NaN
# (962, B)        NaN       NaN       NaN       NaN    ...          NaN
# (962, S)   0.346578       NaN       NaN       NaN    ...          NaN
# (964, S)        NaN       NaN       NaN       NaN    ...          NaN
# (970, B)   0.591667       NaN       NaN  0.425000    ...     0.340000
# (970, S)   0.510000       NaN       NaN  0.510000    ...     0.510000
# (972, B)        NaN       NaN       NaN       NaN    ...          NaN
# (984, B)        NaN       NaN       NaN       NaN    ...          NaN
# (984, S)        NaN       NaN       NaN       NaN    ...     0.510000
# (988, B)        NaN       NaN       NaN       NaN    ...          NaN
# (988, S)   0.510000       NaN       NaN       NaN    ...          NaN
# (990, B)        NaN  0.401875       NaN       NaN    ...          NaN
# (990, S)        NaN  0.386863       NaN       NaN    ...          NaN
# (993, B)   0.350579  0.365782  0.510000  0.385346    ...          NaN
# (993, S)   0.510000  0.505000  0.377004       NaN    ...          NaN
# (995, B)        NaN       NaN       NaN       NaN    ...          NaN
# (995, S)        NaN       NaN       NaN       NaN    ...          NaN
# (996, B)        NaN       NaN       NaN       NaN    ...          NaN
# (996, S)        NaN       NaN       NaN  0.510000    ...          NaN
# (999, S)        NaN       NaN       NaN       NaN    ...          NaN
#
#                  41        42        43        44        45        46  \
# dealer
# (10, B)         NaN       NaN  0.510000       NaN       NaN       NaN
# (10, S)         NaN       NaN       NaN       NaN       NaN       NaN
# (1002, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1005, B)       NaN       NaN       NaN       NaN       NaN  0.372919
# (1016, B)  0.510000  0.301675  0.392938  0.427478  0.420545  0.307787
# (1016, S)  0.510000  0.175002  0.396085  0.556902  0.452407  0.360751
# (1020, B)       NaN       NaN       NaN  0.321497  0.263553       NaN
# (1020, S)       NaN       NaN       NaN       NaN  0.224421       NaN
# (1023, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1023, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1027, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1029, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1029, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1030, B)  0.283972  0.329014  0.285430  0.296350  0.221646  0.254888
# (1030, S)  0.265706  0.271205  0.286594       NaN  0.265088  0.183022
# (1036, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1040, B)       NaN       NaN  0.510000  0.510000  0.340000       NaN
# (1040, S)       NaN       NaN  0.510000  0.695069  0.489135       NaN
# (1042, B)       NaN       NaN       NaN  0.190466  0.226292       NaN
# (1042, S)       NaN       NaN       NaN  0.312790  0.196887  0.142768
# (1043, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1045, B)       NaN       NaN  0.237479  0.495137       NaN       NaN
# (1045, S)       NaN       NaN       NaN       NaN       NaN  0.261402
# (1047, B)       NaN       NaN       NaN  0.458536       NaN       NaN
# (1047, S)  0.510000       NaN       NaN       NaN       NaN       NaN
# (1048, S)       NaN       NaN       NaN       NaN       NaN       NaN
# (1049, B)  0.136798  0.155845       NaN  0.179559  0.205684  0.182838
# (1049, S)       NaN       NaN       NaN  0.237446  0.159523  0.156793
# (1050, B)       NaN       NaN       NaN       NaN       NaN       NaN
# (1050, S)       NaN       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# (949, S)        NaN       NaN  0.608000       NaN  0.463323  0.510000
# (95, B)         NaN       NaN       NaN       NaN       NaN       NaN
# (95, S)         NaN       NaN       NaN       NaN       NaN       NaN
# (950, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (951, B)   0.673333       NaN  0.510000       NaN  0.510000       NaN
# (953, B)        NaN  0.510000       NaN       NaN       NaN       NaN
# (953, S)        NaN       NaN  0.510000       NaN       NaN       NaN
# (956, B)        NaN       NaN       NaN  0.510000  0.510000  0.196492
# (956, S)        NaN       NaN  0.322733       NaN  0.336840  0.766607
# (960, B)        NaN       NaN       NaN       NaN  0.510000       NaN
# (960, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (962, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (962, S)        NaN       NaN       NaN       NaN  0.510000       NaN
# (964, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (970, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (970, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (972, B)        NaN       NaN       NaN       NaN       NaN       NaN
# (984, B)        NaN       NaN  0.510000       NaN       NaN       NaN
# (984, S)        NaN       NaN       NaN       NaN       NaN       NaN
# (988, B)        NaN       NaN  0.510000       NaN       NaN       NaN
# (988, S)        NaN       NaN       NaN       NaN  0.341839       NaN
# (990, B)        NaN       NaN       NaN  0.591667  0.449876  0.424914
# (990, S)        NaN       NaN       NaN       NaN  0.449478  0.510000
# (993, B)        NaN  0.425000       NaN  0.546479  0.432971  0.361638
# (993, S)        NaN       NaN       NaN       NaN  0.673333  0.510000
# (995, B)        NaN  0.510000       NaN       NaN       NaN  0.510000
# (995, S)        NaN       NaN       NaN       NaN       NaN  0.510000
# (996, B)        NaN       NaN       NaN       NaN  0.510000       NaN
# (996, S)        NaN       NaN       NaN       NaN       NaN  0.591667
# (999, S)        NaN       NaN       NaN       NaN  0.510000       NaN
#
#                  47        48        49
# dealer
# (10, B)         NaN       NaN       NaN
# (10, S)         NaN       NaN       NaN
# (1002, B)       NaN       NaN       NaN
# (1005, B)       NaN       NaN       NaN
# (1016, B)  0.550579  0.294889       NaN
# (1016, S)  0.456858  0.333484       NaN
# (1020, B)       NaN       NaN       NaN
# (1020, S)       NaN       NaN  0.340000
# (1023, B)       NaN       NaN       NaN
# (1023, S)       NaN       NaN       NaN
# (1027, B)       NaN       NaN       NaN
# (1029, B)       NaN       NaN  0.510000
# (1029, S)       NaN       NaN       NaN
# (1030, B)  0.254012  0.104316  0.282305
# (1030, S)  0.259220  0.161751  0.174946
# (1036, S)       NaN       NaN       NaN
# (1040, B)  0.510000  0.424564  0.510000
# (1040, S)       NaN       NaN       NaN
# (1042, B)       NaN  0.248960  0.355794
# (1042, S)  0.323909  0.229500  0.372426
# (1043, B)       NaN       NaN       NaN
# (1045, B)       NaN       NaN       NaN
# (1045, S)       NaN       NaN       NaN
# (1047, B)       NaN       NaN       NaN
# (1047, S)       NaN       NaN       NaN
# (1048, S)       NaN       NaN       NaN
# (1049, B)  0.290322  0.221367  0.155730
# (1049, S)  0.242119  0.196341  0.169818
# (1050, B)       NaN       NaN       NaN
# (1050, S)  0.658066       NaN  0.510000
# ...             ...       ...       ...
# (949, S)   0.508333  0.373568  0.673333
# (95, B)         NaN       NaN       NaN
# (95, S)         NaN       NaN       NaN
# (950, S)        NaN  0.836667       NaN
# (951, B)        NaN       NaN       NaN
# (953, B)        NaN       NaN       NaN
# (953, S)        NaN       NaN       NaN
# (956, B)   0.755000       NaN       NaN
# (956, S)   0.657062       NaN  0.344247
# (960, B)        NaN  0.510000       NaN
# (960, S)        NaN       NaN       NaN
# (962, B)        NaN       NaN       NaN
# (962, S)        NaN       NaN       NaN
# (964, S)        NaN       NaN       NaN
# (970, B)        NaN       NaN       NaN
# (970, S)        NaN       NaN       NaN
# (972, B)        NaN       NaN  0.673333
# (984, B)        NaN       NaN       NaN
# (984, S)        NaN       NaN       NaN
# (988, B)        NaN       NaN       NaN
# (988, S)        NaN       NaN       NaN
# (990, B)   0.543039  0.383733  0.381631
# (990, S)   0.649148       NaN  0.398796
# (993, B)   0.554314  0.297506  0.233810
# (993, S)   0.302996  0.188990  0.500025
# (995, B)        NaN  0.510000  0.304435
# (995, S)        NaN       NaN  0.307110
# (996, B)   0.510000       NaN       NaN
# (996, S)   0.673333       NaN       NaN
# (999, S)        NaN       NaN       NaN
#
# [2241 rows x 50 columns]

# %%
Dc_v3.quantile(0.75,axis=1)
# Out:
# 2014-01-09    0.510000
# 2014-01-14    0.673333
# 2014-01-21    0.510000
# 2014-02-07    0.510000
# 2014-02-18    0.510000
# 2014-02-19    0.510000
# 2014-03-06    0.510000
# 2014-03-10    0.510000
# 2014-03-12    0.510000
# 2014-04-01    0.510000
# 2014-04-10    0.340000
# 2014-04-11    0.510000
# 2014-04-14    0.510000
# 2014-05-01    0.510000
# 2014-06-03    0.510000
# 2014-06-10    0.510000
# 2014-06-13    0.673333
# 2014-06-23    0.510000
# 2014-07-01    0.510000
# 2014-07-22    0.510000
# 2014-07-23    0.345220
# 2014-07-25    0.510000
# 2014-08-15    0.510000
# 2014-08-18    0.510000
# 2014-08-19    0.340361
# 2014-08-20    0.371133
# 2014-08-21    0.510000
# 2014-09-04    0.510000
# 2014-09-08    0.510000
# 2014-09-09    0.510000
#                 ...
# 2014-01-22    0.510000
# 2014-02-06    0.510000
# 2014-02-11    0.510000
# 2014-02-19    0.510000
# 2014-02-26    0.510000
# 2014-03-17    0.510000
# 2014-03-18    0.510000
# 2014-03-19    0.357782
# 2014-03-20    0.342704
# 2014-03-31    0.510000
# 2014-06-02    0.510000
# 2014-01-06    0.510000
# 2014-01-31    0.510000
# 2014-02-05    0.510000
# 2014-02-18    0.510000
# 2014-02-25    0.510000
# 2014-03-13    0.510000
# 2014-04-16    0.510000
# 2014-06-12    0.510000
# 2014-06-17    0.340000
# 2014-06-19    0.510000
# 2014-07-14    0.510000
# 2014-07-28    0.510000
# 2014-08-13    0.510000
# 2014-09-12    0.510000
# 2014-09-17    0.510000
# 2014-09-23    0.510000
# 2014-10-07    0.510000
# 2014-10-16    0.510000
# 2014-11-13    0.673333
# Name: 0.75, Length: 157935, dtype: float64

# %%
Dc_v3.groupby(['dealer']).min().describe().T['75%'].plot()

# %%
Dc_v3.groupby(['dealer']).max().describe()
# Out:
#                 0           1           2           3           4           5  \
# count  884.000000  963.000000  936.000000  945.000000  833.000000  741.000000
# mean     0.572257    0.459881    0.516111    0.466555    0.489893    0.522213
# std      0.201569    0.171818    0.193671    0.164237    0.180038    0.184704
# min      0.108376    0.100607    0.100994    0.101629    0.100418    0.101174
# 25%      0.468456    0.339764    0.356896    0.340000    0.355338    0.430298
# 50%      0.528422    0.510000    0.510000    0.510000    0.510000    0.510000
# 75%      0.752553    0.510000    0.673333    0.510000    0.602951    0.673333
# max      0.987273    0.969375    0.988605    0.951706    0.998524    0.992687
#
#                 6           7           8           9     ...              40  \
# count  879.000000  839.000000  712.000000  655.000000     ...      812.000000
# mean     0.470776    0.481766    0.500777    0.496640     ...        0.503141
# std      0.170628    0.182354    0.194897    0.193283     ...        0.187661
# min      0.100178    0.101073    0.105756    0.102522     ...        0.101549
# 25%      0.340000    0.340005    0.346777    0.340344     ...        0.361323
# 50%      0.510000    0.510000    0.510000    0.510000     ...        0.510000
# 75%      0.510000    0.543582    0.673333    0.673333     ...        0.673333
# max      0.984923    0.981154    0.948421    0.975500     ...        0.958171
#
#                41          42          43          44           45  \
# count  756.000000  723.000000  912.000000  792.000000  1036.000000
# mean     0.501363    0.440466    0.537848    0.504492     0.503977
# std      0.183875    0.178556    0.195829    0.190458     0.171813
# min      0.100125    0.105985    0.100098    0.100661     0.100313
# 25%      0.359357    0.303427    0.456889    0.343429     0.422382
# 50%      0.510000    0.510000    0.510000    0.510000     0.510000
# 75%      0.670634    0.510000    0.673333    0.673333     0.621571
# max      0.997322    0.957391    0.983934    0.972455     0.965000
#
#                46          47          48          49
# count  830.000000  896.000000  768.000000  964.000000
# mean     0.455869    0.568696    0.466973    0.476315
# std      0.188098    0.200305    0.200593    0.169793
# min      0.101302    0.108584    0.101128    0.103058
# 25%      0.321840    0.474554    0.323587    0.340611
# 50%      0.510000    0.510000    0.510000    0.510000
# 75%      0.510000    0.706224    0.570205    0.510000
# max      0.992283    0.979149    0.976667    0.902000
#
# [8 rows x 50 columns]

# %%
Dc_v3.groupby(['dealer']).max().describe().T['75%'].plot()
